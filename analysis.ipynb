# %%
import pandas as pd

# %%
data=pd.read_csv('diabetes_prediction_dataset.csv')

data.head()
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi
# 27241  Female  11.0             0              0         No Info  20.85  \
#
#        HbA1c_level  blood_glucose_level  diabetes
# 27241          6.5                   85         0

# %%
data.tail()
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi
# 99995  Female  80.0             0              0         No Info  27.32  \
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 99995          6.2                   90         0
# 99996          6.5                  100         0
# 99997          5.7                  155         0
# 99998          4.0                  100         0
# 99999          6.6                   90         0

# %%
data.sample()
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi
# 67932  Female  15.0             0              0           never  19.57  \
#
#        HbA1c_level  blood_glucose_level  diabetes
# 67932          5.7                   85         0

# %%
data.describe()
# Out:
#                  age  hypertension  heart_disease            bmi
# count  100000.000000  100000.00000  100000.000000  100000.000000  \
# mean       41.885856       0.07485       0.039420      27.320767
# std        22.516840       0.26315       0.194593       6.636783
# min         0.080000       0.00000       0.000000      10.010000
# 25%        24.000000       0.00000       0.000000      23.630000
# 50%        43.000000       0.00000       0.000000      27.320000
# 75%        60.000000       0.00000       0.000000      29.580000
# max        80.000000       1.00000       1.000000      95.690000
#
#          HbA1c_level  blood_glucose_level       diabetes
# count  100000.000000        100000.000000  100000.000000
# mean        5.527507           138.058060       0.085000
# std         1.070672            40.708136       0.278883
# min         3.500000            80.000000       0.000000
# 25%         4.800000           100.000000       0.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   gender               100000 non-null  object
#  1   age                  100000 non-null  float64
#  2   hypertension         100000 non-null  int64
#  3   heart_disease        100000 non-null  int64
#  4   smoking_history      100000 non-null  object
#  5   bmi                  100000 non-null  float64
#  6   HbA1c_level          100000 non-null  float64
#  7   blood_glucose_level  100000 non-null  int64
#  8   diabetes             100000 non-null  int64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 6.9+ MB

# %%
data.isnull().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %%
mapping = {'Male' : 1,'Female' : 0}
data['gender_i'] = data['gender'].map(mapping) 
data
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi
# 0      Female  80.0             0              1           never  25.19  \
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes  gender_i
# ...

# %%
data_i = data.drop(['gender'], axis = 1)
data_i
# Out:
#         age  hypertension  heart_disease smoking_history    bmi  HbA1c_level
# 0      80.0             0              1           never  25.19          6.6  \
# 1      54.0             0              0         No Info  27.32          6.6
# 2      28.0             0              0           never  27.32          5.7
# 3      36.0             0              0         current  23.45          5.0
# 4      76.0             1              1         current  20.14          4.8
# ...     ...           ...            ...             ...    ...          ...
# 99995  80.0             0              0         No Info  27.32          6.2
# 99996   2.0             0              0         No Info  17.37          6.5
# 99997  66.0             0              0          former  27.83          5.7
# 99998  24.0             0              0           never  35.42          4.0
# 99999  57.0             0              0         current  22.43          6.6
#
# ...

# %%
data_i['smoking_history'].value_counts()
# Out:
# smoking_history
# No Info        35816
# never          35095
# former          9352
# current         9286
# not current     6447
# ever            4004
# Name: count, dtype: int64

# %%
data_i[data_i['smoking_history'] == 'ever']
# Out:
#         age  hypertension  heart_disease smoking_history    bmi  HbA1c_level
# 19     37.0             0              0            ever  25.72          3.5  \
# 65     59.0             0              1            ever  23.11          6.5
# 88     38.0             0              0            ever  22.42          6.0
# 103    55.0             0              0            ever  18.60          6.0
# 156    54.0             0              0            ever  26.72          6.1
# ...     ...           ...            ...             ...    ...          ...
# 99895  74.0             0              0            ever  27.32          3.5
# 99949  26.0             0              0            ever  21.50          6.5
# 99953  59.0             1              0            ever  60.52          3.5
# 99956  26.0             0              0            ever  25.60          6.6
# 99970  32.0             0              0            ever  37.71          6.1
#
# ...

# %%
data_res.hist(bins=60, figsize=(20,10))
# Out:
# array([[<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'hypertension'}>],
#        [<Axes: title={'center': 'heart_disease'}>,
#         <Axes: title={'center': 'bmi'}>],
#        [<Axes: title={'center': 'HbA1c_level'}>,
#         <Axes: title={'center': 'blood_glucose_level'}>]], dtype=object)

# %%
cnt = len(data_res[data_res ['bmi'] > 60])
cnt
# Out:
# 46

# %%
high_bmi = data_res[data_res ['bmi'] > 60]
high_bmi
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 high_bmi = data_res[data_res ['bmi'] > 60]
#       2 high_bmi
#
# NameError: name 'data_res' is not defined

# %%
high_bmi.hist(bins=60, figsize=(20,10))
# Out:
# array([[<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'hypertension'}>],
#        [<Axes: title={'center': 'heart_disease'}>,
#         <Axes: title={'center': 'bmi'}>],
#        [<Axes: title={'center': 'HbA1c_level'}>,
#         <Axes: title={'center': 'blood_glucose_level'}>]], dtype=object)

# %%
data_res['gender'].value_counts()
# Out:
# gender
# Female    9488
# Male      7512
# Name: count, dtype: int64

# %%
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi
# 0        Male  26.0             0              0     not current  27.32  \
# 1        Male   0.8             0              0         No Info  20.22
# 2        Male  24.0             0              0           never  46.10
# 3        Male  65.0             0              0          former  29.70
# 4        Male  54.0             0              0         No Info  27.32
# ...       ...   ...           ...            ...             ...    ...
# 16995  Female  65.0             1              1           never  33.55
# 16996    Male  55.0             0              1          former  30.42
# 16997  Female  61.0             0              0         No Info  34.45
# 16998  Female  58.0             1              0           never  38.31
# 16999  Female  61.0             0              0         current  30.11
#
#        HbA1c_level  blood_glucose_level  gender_i
# 0              6.6                   85         1
# ...

# %%
data_i
# Out:
#         age  hypertension  heart_disease smoking_history    bmi  HbA1c_level
# 0      26.0             0              0     not current  27.32          6.6  \
# 1       0.8             0              0         No Info  20.22          6.5
# 2      24.0             0              0           never  46.10          6.0
# 3      65.0             0              0          former  29.70          4.5
# 4      54.0             0              0         No Info  27.32          4.5
# ...     ...           ...            ...             ...    ...          ...
# 16995  65.0             1              1           never  33.55          8.2
# 16996  55.0             0              1          former  30.42          6.2
# 16997  61.0             0              0         No Info  34.45          6.5
# 16998  58.0             1              0           never  38.31          7.0
# 16999  61.0             0              0         current  30.11          6.2
#
#        blood_glucose_level  gender_i
# ...

# %%
sm_y = data_i['smoking_history']

sm_y.value_counts()
# Out:
# smoking_history
# never          6317
# No Info        4667
# former         2317
# current        1698
# not current    1201
# ever            800
# Name: count, dtype: int64

# %%
ever_d = data_i(data_i['smoking_history'] == 'ever')
ever_d
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 ever_d = data_i(data_i['smoking_history'] == 'ever')
#       2 ever_d
#
# TypeError: 'DataFrame' object is not callable
